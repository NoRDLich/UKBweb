# %%
# 单元格 1: 导入必要的库
import dxpy
import numpy as np
import pandas as pd
import re
import subprocess
import glob
import os
import shlex # 用于安全地分割命令行参数

print("库导入完成。")
# Out:
# 库导入完成。

# %%
# 单元格 2: 定义辅助函数

def convert_phenotype_name(ukb_name):
    """
    将 UK Biobank 表型名称转换为 R 兼容的格式 'x[varid]_[instance]_[array]'。
    示例: 'p12345_i0_a0' 变为 'x12345_0_0'
             'eid' 变为 'userId'
    """
    if ukb_name == 'eid':
        return 'userId'

    # 尝试匹配 p<varid>_i<instance>_a<array> 格式
    match_standard = re.match(r'p(\d+)(?:_i(\d+))?(?:_a(\d+))?$', ukb_name)
    if match_standard:
        varid = match_standard.group(1)
        instance = match_standard.group(2) if match_standard.group(2) is not None else '0'
        array = match_standard.group(3) if match_standard.group(3) is not None else '0'
        return f'x{varid}_{instance}_{array}'
    else:
        # 对于不完全匹配上述格式的名称 (例如，只有 varid)
        match_simple_p = re.match(r'p(\d+)$', ukb_name)
        if match_simple_p:
            varid = match_simple_p.group(1)
            return f'x{varid}_0_0' # 默认为 instance 0, array 0

        # 对于其他不以 'p' 开头或不符合上述规则的名称，进行通用 R 兼容性处理
        r_compatible_name = re.sub(r'[^a-zA-Z0-9_.]', '_', ukb_name) # 允许点号
        if not r_compatible_name: # 如果替换后为空
            return f"unknown_field_{ukb_name}"
        if r_compatible_name[0].isdigit():
            r_compatible_name = 'x' + r_compatible_name
        # 确保名称在 R 中有效（例如，不能以下划线或点开头，尽管 R 本身有时允许）
        if r_compatible_name.startswith('_') or r_compatible_name.startswith('.'):
            r_compatible_name = 'x' + r_compatible_name
        return r_compatible_name

# %%
# 单元格 3: 自动发现数据集和项目 ID
dispensed_dataset_id = None
project_id = None
dataset_full_id = None

try:
    dispensed_dataset_obj = dxpy.find_one_data_object(
        typename="Dataset", name="app*.dataset", folder="/", name_mode="glob", return_handler=False
    )
    if not dispensed_dataset_obj:
        raise Exception("错误：未找到分发的数据集。请确保根目录中存在名为 'app*.dataset' 的数据集。")
    dispensed_dataset_id = dispensed_dataset_obj["id"]
    print(f"找到分发的数据集 ID: {dispensed_dataset_id}")

    project_obj = dxpy.find_one_project(return_handler=False)
    if not project_obj:
        raise Exception("错误：未能找到当前项目。")
    project_id = project_obj["id"]
    print(f"找到项目 ID: {project_id}")

    dataset_full_id = f"{project_id}:{dispensed_dataset_id}"
    print(f"将使用数据集: {dataset_full_id}")

except Exception as e:
    print(f"初始化错误: {e}")
    # 如果在notebook中，你可能希望在这里停止执行或进行手动干预
    # raise e # 或者重新抛出异常以停止notebook
# Out:
# 找到分发的数据集 ID: record-GvQp8V8JJ68073BBp2PjfgKg
# 找到项目 ID: project-GvQgb10JjKY3XGbpZbGVg0v3
# 将使用数据集: project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg

# %%
# 单元格 4: 提取或加载数据字典
current_path = os.getcwd()
data_dict_filename = ""
data_dict_df = None

# 检查数据字典文件是否已存在
existing_dict_files = glob.glob(os.path.join(current_path, "*.data_dictionary.csv"))
if existing_dict_files:
    data_dict_filename = existing_dict_files[0]
    print(f"找到已存在的数据字典: {data_dict_filename}")
else:
    if dataset_full_id:
        print("本地未找到数据字典，尝试从数据集中提取...")
        cmd_extract_dict = ["dx", "extract_dataset", dataset_full_id, "-ddd", "--delimiter", ","]
        try:
            print(f"执行命令: {shlex.join(cmd_extract_dict)}")
            subprocess.check_call(cmd_extract_dict)
            downloaded_dicts = glob.glob(os.path.join(current_path, "*.data_dictionary.csv"))
            if downloaded_dicts:
                data_dict_filename = downloaded_dicts[0]
                print(f"成功提取并找到数据字典: {data_dict_filename}")
            else:
                raise Exception("错误：提取后未能找到数据字典文件。")
        except subprocess.CalledProcessError as e:
            print(f"提取数据集字典时出错: {e}")
            downloaded_dicts = glob.glob(os.path.join(current_path, "*.data_dictionary.csv"))
            if downloaded_dicts: # 尝试查找是否已部分创建或错误是由于重复运行造成的
                data_dict_filename = downloaded_dicts[0]
                print(f"尽管子流程出错，但找到了数据字典 (可能已存在或部分创建): {data_dict_filename}")
            else:
                print("由于提取数据字典失败，中止操作。")
        except Exception as e:
            print(f"提取字典时发生意外错误: {e}")
    else:
        print("错误：数据集 ID 未定义，无法提取数据字典。")


# 读取数据字典
if data_dict_filename:
    try:
        data_dict_df = pd.read_csv(data_dict_filename, low_memory=False)
        print("数据字典加载成功。")
        # display(data_dict_df.head()) # 在RAP环境中，display可能不可用，用print替代
        print("数据字典 (前5行):")
        print(data_dict_df.head())
    except Exception as e:
        print(f"读取数据字典 CSV '{data_dict_filename}' 时出错: {e}")
        data_dict_df = None #确保后续检查能识别失败
else:
    print("未能获取数据字典文件名，无法加载。")
# Out:
# 本地未找到数据字典，尝试从数据集中提取...
# 执行命令: dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg -ddd --delimiter ,
# 成功提取并找到数据字典: /opt/notebooks/app83497_20241030011331.dataset.data_dictionary.csv
# 数据字典加载成功。
# 数据字典 (前5行):
#         entity   name     type primary_key_type coding_name  concept  \
# 0  participant    eid   string           global         NaN      NaN
# 1  participant  p3_i0  integer              NaN         NaN      NaN
# 2  participant  p3_i1  integer              NaN         NaN      NaN
# 3  participant  p3_i2  integer              NaN         NaN      NaN
# 4  participant  p3_i3  integer              NaN         NaN      NaN
#
#    description                                        folder_path  \
# 0          NaN                            Participant Information
# 1          NaN  Assessment centre > Procedural metrics > Proce...
# 2          NaN  Assessment centre > Procedural metrics > Proce...
# 3          NaN  Assessment centre > Procedural metrics > Proce...
# 4          NaN  Assessment centre > Procedural metrics > Proce...
#
#   is_multi_select is_sparse_coding  \
# 0             NaN              NaN
# 1             NaN              NaN
# 2             NaN              NaN
# 3             NaN              NaN
# 4             NaN              NaN
#
#                                              linkout  longitudinal_axis_type  \
# 0                                                NaN                     NaN
# 1  http://biobank.ctsu.ox.ac.uk/crystal/field.cgi...                     NaN
# 2  http://biobank.ctsu.ox.ac.uk/crystal/field.cgi...                     NaN
# 3  http://biobank.ctsu.ox.ac.uk/crystal/field.cgi...                     NaN
# 4  http://biobank.ctsu.ox.ac.uk/crystal/field.cgi...                     NaN
#
#   referenced_entity_field relationship  \
# 0                     NaN          NaN
# 1                     NaN          NaN
# 2                     NaN          NaN
# 3                     NaN          NaN
# 4                     NaN          NaN
#
#                                     title    units
# 0                          Participant ID      NaN
# 1  Verbal interview duration | Instance 0  seconds
# 2  Verbal interview duration | Instance 1  seconds
# 3  Verbal interview duration | Instance 2  seconds
# 4  Verbal interview duration | Instance 3  seconds

# %%
# 单元格 5: 定义 fields_for_id 函数 (来自 06 脚本)
# 这个函数需要 data_dict_df 已经加载完毕

def fields_for_id(field_ids_list, data_dictionary_df):
    """
    根据提供的 field_id 列表，从数据字典中构建用于 dx extract_dataset 的字段字符串。
    确保 eid 始终被包含，并且字段属于 'participant' 实体。
    """
    if data_dictionary_df is None:
        print("错误: fields_for_id 需要一个有效的数据字典 DataFrame。")
        return None

    # 始终包含 participant.eid
    final_field_names_to_extract = ["participant.eid"]
    
    # 从数据字典中筛选出 'participant' 实体的字段
    participant_data_dict = data_dictionary_df[data_dictionary_df['entity'] == 'participant']

    for _id in field_ids_list:
        # 构建正则表达式以匹配字段ID，包括可能的实例和数组后缀
        # 例如, field_id '3' 应该匹配 'p3', 'p3_i0', 'p3_i0_a0' 等
        regex_pattern = r"^p{}(?:_i\d+)?(?:_a\d+)?$".format(re.escape(str(_id)))
        
        select_field_names = list(
            participant_data_dict[
                participant_data_dict.name.str.match(regex_pattern, na=False)
            ].name.values
        )
        
        for fname in select_field_names:
            qualified_name = f"participant.{fname}"
            if qualified_name not in final_field_names_to_extract: # 确保唯一性
                 final_field_names_to_extract.append(qualified_name)
    
    if len(final_field_names_to_extract) == 1 and "participant.eid" in final_field_names_to_extract:
        print(f"警告: 除了 'eid' 外，没有找到与提供的 ID 列表匹配的 'participant' 实体字段: {field_ids_list}")
        return "participant.eid" # 只返回eid，避免提取空数据导致错误

    return ",".join(final_field_names_to_extract)

print("fields_for_id 函数定义完成。")
# Out:
# fields_for_id 函数定义完成。

# %%
# 单元格 6: 获取所有表型名称并构建提取列表
all_phenotype_ukb_names_from_dict = [] # UKB原始名称，如 pXXXX_iY_aZ
all_phenotype_field_ids_for_extraction = [] # 仅包含数字ID，如 XXXX
fields_to_extract_str = ""

if data_dict_df is not None:
    # 1. 获取所有可能的表型名 (name 列)
    # 我们只对 'participant' entity 感兴趣
    participant_fields_df = data_dict_df[data_dict_df['entity'] == 'participant']
    
    # 提取所有在 'name' 列中的有效表型字段 (通常以 'p' 开头)
    # 并确保 'eid' 存在
    raw_names = participant_fields_df['name'].dropna().astype(str).unique().tolist()
    
    if 'eid' not in raw_names:
        all_phenotype_ukb_names_from_dict.append('eid') # 确保userId列的基础'eid'存在

    for name in raw_names:
        if name not in all_phenotype_ukb_names_from_dict: # 避免重复
            all_phenotype_ukb_names_from_dict.append(name)
        
        # 从表型名称 (如 'p3_i0', 'p21003_i0_a0', 'p41270') 中提取数字ID部分
        match_p_id = re.match(r'p(\d+)', name)
        if match_p_id:
            field_id_num = match_p_id.group(1)
            if field_id_num not in all_phenotype_field_ids_for_extraction:
                all_phenotype_field_ids_for_extraction.append(field_id_num)
        elif name != 'eid': # 其他非'p'开头的也尝试加入，如果需要的话
            # 根据您的数据字典，这里可能不需要添加非'p'开头的，除非有特殊情况
            pass
            
    print(f"从数据字典的 'participant' 实体中找到 {len(all_phenotype_ukb_names_from_dict)} 个原始表型名称。")
    print(f"提取到 {len(all_phenotype_field_ids_for_extraction)} 个唯一的表型数字ID。")
    # print(f"原始表型名称示例 (前10): {all_phenotype_ukb_names_from_dict[:10]}")
    # print(f"表型数字ID示例 (前10): {all_phenotype_field_ids_for_extraction[:10]}")

    # 2. 使用 fields_for_id 函数来构建提取字符串
    # 注意：如果表型ID列表过长，直接作为命令行参数可能会超限。
    # dx extract_dataset 也接受 --fields-file 参数，这更适合大量字段。
    # 这里我们先用 fields_for_id 准备要传递给 --fields-file 的 *原始* UKB 字段名列表 (不含 participant. 前缀)
    
    # fields_for_id 函数是设计来接收数字ID列表的。
    # 我们需要的是所有 'participant.pXXXX...' 格式的字段
    # 我们已经有了 all_phenotype_ukb_names_from_dict，其中包含了 'eid' 和所有 'pXXXX...'
    
    fields_to_extract_for_file = []
    if 'eid' in all_phenotype_ukb_names_from_dict:
        fields_to_extract_for_file.append('eid') # dx extract_dataset --fields-file 需要的是不带 entity 前缀的名称
    
    for name in all_phenotype_ukb_names_from_dict:
        if name.startswith('p') and name not in fields_to_extract_for_file:
            fields_to_extract_for_file.append(name)
    
    print(f"准备了 {len(fields_to_extract_for_file)} 个字段写入 --fields-file。")

else:
    print("数据字典未成功加载，无法获取表型名称。")
# Out:
# 从数据字典的 'participant' 实体中找到 29378 个原始表型名称。
# 提取到 9460 个唯一的表型数字ID。
# 准备了 29378 个字段写入 --fields-file。

# %%
# 单元格 7: 提取表型数据 (分批处理)
output_phenotype_csv_name = "all_phenotypes_extracted_raw.csv" # 最终合并的原始文件名
phenotype_df = None # 这将是最终合并的 DataFrame
list_of_batch_dfs = []
temp_batch_files_to_delete = []


output_phenotype_csv_name = "all_phenotypes_extracted_raw_from_batch49_onwards.csv" # 最终合并的原始文件名
phenotype_df = None # 这将是最终合并的 DataFrame
list_of_batch_dfs = [] # 只存储从 start_batch_index 开始新提取的批次
temp_batch_files_to_delete = [] # 本次运行中创建的临时文件

# --- 确保以下变量已由之前的单元格正确定义和加载 ---
# data_dict_df: Pandas DataFrame，数据字典
# all_phenotype_field_ids_for_extraction: Python list，包含所有待提取表型的数字ID字符串 (不含'eid')
# dataset_full_id: 字符串, 格式如 "project-XXXX:record-YYYY"
# fields_for_id: 函数，用于根据ID列表生成 --fields 字符串
# shlex: 模块，shlex.join 用于安全地显示命令
# ---------------------------------------------------------

if (data_dict_df is not None and
        'all_phenotype_field_ids_for_extraction' in globals() and
        all_phenotype_field_ids_for_extraction and # 确保列表不是None也不是空的
        dataset_full_id):
    
    field_ids_to_process = all_phenotype_field_ids_for_extraction.copy() 
    
    batch_size = 1 # 您之前设定的每个表型ID一批
    num_total_batches = (len(field_ids_to_process) + batch_size - 1) // batch_size # 计算总批次数
    
    print(f"总共可处理的表型ID数量: {len(field_ids_to_process)}.")
    print(f"总理论批次数: {num_total_batches}，每批最多 {batch_size} 个表型ID。")

    # --- 从第49个索引 (即第50个批次) 开始提取 ---
    start_batch_index = 49 
    # ---------------------------------------------

    if start_batch_index >= num_total_batches:
        print(f"起始批次索引 {start_batch_index} 超出或等于总批次数 {num_total_batches}。无需提取新批次。")
    else:
        print(f"将从批次索引 {start_batch_index} (即第 {start_batch_index + 1} 个批次) 开始执行，直到批次索引 {num_total_batches - 1}。")

        for i in range(start_batch_index, num_total_batches):
            current_loop_batch_number = i + 1 # 用户友好的批次号 (从1开始)
            
            # 从 field_ids_to_process 中获取当前批次的ID
            current_slice_start = i * batch_size
            current_slice_end = current_slice_start + batch_size
            current_batch_field_ids = field_ids_to_process[current_slice_start:current_slice_end]

            if not current_batch_field_ids: # 理论上在 range(start_batch_index, num_total_batches) 内不应发生
                print(f"警告: 批次 {current_loop_batch_number} (索引 {i}) 的表型ID列表为空，跳过。")
                continue

            print(f"\n正在处理批次 {current_loop_batch_number}/{num_total_batches} (索引 {i})，包含 {len(current_batch_field_ids)} 个表型ID(s)...")
            
            batch_fields_str = fields_for_id(current_batch_field_ids, data_dict_df)
            
            if not batch_fields_str or (batch_fields_str == "participant.eid" and current_batch_field_ids):
                print(f"警告: 批次 {current_loop_batch_number} 未能从ID列表 {current_batch_field_ids} 中找到任何有效字段（除了eid），跳过此提取批次。")
                continue
            
            batch_output_filename = f"temp_pheno_batch_{i}.csv" # 文件名使用当前循环索引 i
            temp_batch_files_to_delete.append(batch_output_filename)

            # 如果希望每次都强制重新提取，可以取消下面这块检查已存在文件的逻辑
            # if os.path.exists(batch_output_filename) and os.path.getsize(batch_output_filename) > 0:
            #     print(f"批次文件 {batch_output_filename} 已存在。为确保最新数据，将重新提取。")
            #     try: os.remove(batch_output_filename)
            #     except OSError as e_del_old: print(f"删除旧批次文件 {batch_output_filename} 失败: {e_del_old}")
            # 或者，如果想跳过已存在的：
            # if os.path.exists(batch_output_filename) and os.path.getsize(batch_output_filename) > 0:
            #     print(f"批次文件 {batch_output_filename} 已存在且非空，尝试加载。")
            #     try:
            #         batch_df = pd.read_csv(batch_output_filename, low_memory=False)
            #         if "participant.eid" not in batch_df.columns:
            #             if "eid" in batch_df.columns: batch_df.rename(columns={"eid": "participant.eid"}, inplace=True)
            #             else: raise ValueError("eid列缺失")
            #         list_of_batch_dfs.append(batch_df)
            #         print(f"已从现有文件加载批次 {current_loop_batch_number} 数据。Shape: {batch_df.shape}")
            #         continue # 跳过提取
            #     except Exception as e_load: print(f"加载文件 {batch_output_filename} 失败 ({e_load})，将尝试重新提取。")
            
            # 强制重新提取（如果需要，或者上面跳过逻辑未执行）
            cmd_extract_batch = [
                "dx", "extract_dataset", dataset_full_id,
                "--fields", batch_fields_str,
                "--delimiter", ",",
                "--output", batch_output_filename,
            ]

            print(f"执行命令 (批次 {current_loop_batch_number}): {shlex.join(cmd_extract_batch)}")
            process = subprocess.run(cmd_extract_batch, capture_output=True, text=True, check=False)

            if process.returncode == 0:
                if process.stdout: print(f"dx STDOUT (批次 {current_loop_batch_number}):\n{process.stdout}")
                if process.stderr: print(f"dx STDERR (批次 {current_loop_batch_number}, 可能包含成功摘要):\n{process.stderr}")

                if os.path.exists(batch_output_filename) and os.path.getsize(batch_output_filename) > 0:
                    try:
                        batch_df = pd.read_csv(batch_output_filename, low_memory=False)
                        if "participant.eid" not in batch_df.columns:
                            potential_eid_col = "eid" if "eid" in batch_df.columns else None
                            if potential_eid_col:
                                batch_df.rename(columns={potential_eid_col: "participant.eid"}, inplace=True)
                            else:
                                print(f"错误: 批次 {current_loop_batch_number} 输出文件 '{batch_output_filename}' 中未找到 'participant.eid' 或 'eid' 列。跳过。")
                                continue
                        list_of_batch_dfs.append(batch_df)
                        print(f"批次 {current_loop_batch_number} 数据加载成功。DataFrame shape: {batch_df.shape}")
                    except Exception as e_read:
                        print(f"读取批次 {current_loop_batch_number} 的 CSV '{batch_output_filename}' 时出错: {e_read}")
                else:
                    print(f"错误: 批次 {current_loop_batch_number} 提取命令成功，但输出文件 '{batch_output_filename}' 未创建或为空。")
            else:
                print(f"执行批次 {current_loop_batch_number} 的 'dx extract_dataset' 时出错。返回码: {process.returncode}")
                print(f"STDERR (批次 {current_loop_batch_number}):\n{process.stderr if process.stderr else '无 STDERR 输出。'}")
                print(f"STDOUT (批次 {current_loop_batch_number}):\n{process.stdout if process.stdout else '无 STDOUT 输出。'}")
                print(f"批次 {current_loop_batch_number} 失败，建议检查错误并决定是否中止整个过程。当前设置为继续处理后续批次。")
                # 若要在一个批次失败时停止，取消下面一行的注释：
                # break 

        # --- 合并从 start_batch_index 开始提取的所有批次的 DataFrame ---
        if list_of_batch_dfs: # 确保至少有一个批次成功加载
            print(f"\n开始合并 {len(list_of_batch_dfs)} 个新提取的批次 (从索引 {start_batch_index} 开始)...")
            merge_key = "participant.eid" 
            
            phenotype_df = list_of_batch_dfs[0] # 第一个成功加载的批次作为基础
            if merge_key not in phenotype_df.columns:
                print(f"错误：第一个用于合并的DataFrame中缺少合并键 '{merge_key}'。其列为: {phenotype_df.columns.tolist()}")
                phenotype_df = None # 阻止后续操作
            else:
                print(f"基础 DataFrame (来自批次索引 {temp_batch_files_to_delete[0].split('_')[-1].split('.')[0]}) shape: {phenotype_df.shape}")

                for k in range(1, len(list_of_batch_dfs)):
                    df_to_merge = list_of_batch_dfs[k]
                    df_to_merge_filename = temp_batch_files_to_delete[k] # 获取对应文件名用于日志
                    print(f"准备合并来自文件 '{df_to_merge_filename}' 的DataFrame (shape: {df_to_merge.shape})")
                    
                    if merge_key not in df_to_merge.columns:
                        print(f"错误: 合并键 '{merge_key}' 在文件 '{df_to_merge_filename}' 的DataFrame中未找到。跳过合并此批次。")
                        continue
                    
                    # 只合并新的列 (除了合并键)
                    new_cols_to_add = [col for col in df_to_merge.columns if col not in phenotype_df.columns or col == merge_key]
                    if not new_cols_to_add or (len(new_cols_to_add) == 1 and new_cols_to_add[0] == merge_key):
                        print(f"文件 '{df_to_merge_filename}' 没有新的列（除了合并键）可以添加到主DataFrame，跳过合并。")
                        continue
                    df_to_merge_selected = df_to_merge[new_cols_to_add]

                    try:
                        phenotype_df = pd.merge(phenotype_df, df_to_merge_selected, on=merge_key, how='outer')
                        print(f"合并后 DataFrame shape: {phenotype_df.shape}")
                    except Exception as e_merge:
                        print(f"合并文件 '{df_to_merge_filename}' 的DataFrame时出错: {e_merge}")
            
            if phenotype_df is not None:
                 print("所有指定批次合并完成。")
                 print(f"最终合并的原始 DataFrame (从批次索引 {start_batch_index} 开始) shape: {phenotype_df.shape}")
                 # 可以选择在这里保存这个中间的合并结果，或者等待单元格8和9的处理
                 # phenotype_df.to_csv(f"temp_merged_from_batch_{start_batch_index}.csv", index=False)
            else:
                print("错误：合并后 phenotype_df 为 None 或未成功初始化。")
        else:
            print("没有从指定起始批次成功提取或加载的数据可供合并。")

        # 清理本次运行中创建的临时批处理文件
        print("\n清理本次运行中创建的临时批处理文件...")
        for temp_file in temp_batch_files_to_delete:
            if os.path.exists(temp_file):
                try:
                    os.remove(temp_file)
                    print(f"已删除临时文件: {temp_file}")
                except OSError as e_rem_temp:
                    print(f"删除临时文件 '{temp_file}' 时出错: {e_rem_temp}")
else:
    if data_dict_df is None: print("数据字典 (data_dict_df) 未加载。")
    if 'all_phenotype_field_ids_for_extraction' not in globals() or not all_phenotype_field_ids_for_extraction:
        print("表型字段ID列表 (all_phenotype_field_ids_for_extraction) 未定义或为空。")
    if not dataset_full_id: print("数据集ID (dataset_full_id) 未定义。")
    print("因此跳过表型数据提取步骤。")

# phenotype_df 现在将包含从批次索引 start_batch_index 开始提取并合并的数据。
# 后续的单元格 8 (重命名和排序列) 将基于这个 phenotype_df 进行操作。
# 如果 phenotype_df 为 None (因为没有批次成功)，单元格8和9应该能正确处理这种情况。
# Out:
# 总共可处理的表型ID数量: 9460.
# 总理论批次数: 9460，每批最多 1 个表型ID。
# 将从批次索引 49 (即第 50 个批次) 开始执行，直到批次索引 9459。
#
# 正在处理批次 50/9460 (索引 49)，包含 1 个表型ID(s)...
# 执行命令 (批次 50): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p136_i0,participant.p136_i1,participant.p136_i2,participant.p136_i3 --delimiter , --output temp_pheno_batch_49.csv
# dx STDERR (批次 50, 可能包含成功摘要):
# WARNING:dxpy:[Sat May 17 06:55:53 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747464944.3002534, Request ID=unavailable. Waiting 1 seconds before retry 1 of 6...
# INFO:dxpy:[Sat May 17 06:56:15 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: Recovered after 1 retries
#
# 批次 50 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 51/9460 (索引 50)，包含 1 个表型ID(s)...
# 执行命令 (批次 51): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p137_i0,participant.p137_i1,participant.p137_i2,participant.p137_i3 --delimiter , --output temp_pheno_batch_50.csv
# 批次 51 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 52/9460 (索引 51)，包含 1 个表型ID(s)...
# 执行命令 (批次 52): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p190 --delimiter , --output temp_pheno_batch_51.csv
# 批次 52 数据加载成功。DataFrame shape: (502137, 2)
#
# 正在处理批次 53/9460 (索引 52)，包含 1 个表型ID(s)...
# 执行命令 (批次 53): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p191 --delimiter , --output temp_pheno_batch_52.csv
# 批次 53 数据加载成功。DataFrame shape: (502137, 2)
#
# 正在处理批次 54/9460 (索引 53)，包含 1 个表型ID(s)...
# 执行命令 (批次 54): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p200 --delimiter , --output temp_pheno_batch_53.csv
# 批次 54 数据加载成功。DataFrame shape: (502137, 2)
#
# 正在处理批次 55/9460 (索引 54)，包含 1 个表型ID(s)...
# 执行命令 (批次 55): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p393 --delimiter , --output temp_pheno_batch_54.csv
# 批次 55 数据加载成功。DataFrame shape: (502137, 2)
#
# 正在处理批次 56/9460 (索引 55)，包含 1 个表型ID(s)...
# 执行命令 (批次 56): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p396_i0_a1,participant.p396_i0_a2,participant.p396_i0_a3,participant.p396_i1_a1,participant.p396_i1_a2,participant.p396_i1_a3,participant.p396_i2_a1,participant.p396_i2_a2,participant.p396_i2_a3,participant.p396_i3_a1,participant.p396_i3_a2,participant.p396_i3_a3 --delimiter , --output temp_pheno_batch_55.csv
# dx STDERR (批次 56, 可能包含成功摘要):
# WARNING:dxpy:[Sat May 17 06:58:24 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747465084.3220503, Request ID=unavailable. Waiting 1 seconds before retry 1 of 6...
# INFO:dxpy:[Sat May 17 06:58:37 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: Recovered after 1 retries
#
# 批次 56 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 57/9460 (索引 56)，包含 1 个表型ID(s)...
# 执行命令 (批次 57): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p397_i0_a1,participant.p397_i0_a2,participant.p397_i1_a1,participant.p397_i1_a2,participant.p397_i2_a1,participant.p397_i2_a2,participant.p397_i3_a1,participant.p397_i3_a2 --delimiter , --output temp_pheno_batch_56.csv
# 批次 57 数据加载成功。DataFrame shape: (502137, 9)
#
# 正在处理批次 58/9460 (索引 57)，包含 1 个表型ID(s)...
# 执行命令 (批次 58): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p398_i0_a1,participant.p398_i0_a2,participant.p398_i0_a3,participant.p398_i1_a1,participant.p398_i1_a2,participant.p398_i1_a3,participant.p398_i2_a1,participant.p398_i2_a2,participant.p398_i2_a3,participant.p398_i3_a1,participant.p398_i3_a2,participant.p398_i3_a3 --delimiter , --output temp_pheno_batch_57.csv
# 批次 58 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 59/9460 (索引 58)，包含 1 个表型ID(s)...
# 执行命令 (批次 59): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p399_i0_a1,participant.p399_i0_a2,participant.p399_i0_a3,participant.p399_i1_a1,participant.p399_i1_a2,participant.p399_i1_a3,participant.p399_i2_a1,participant.p399_i2_a2,participant.p399_i2_a3,participant.p399_i3_a1,participant.p399_i3_a2,participant.p399_i3_a3 --delimiter , --output temp_pheno_batch_58.csv
# 批次 59 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 60/9460 (索引 59)，包含 1 个表型ID(s)...
# 执行命令 (批次 60): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p400_i0_a1,participant.p400_i0_a2,participant.p400_i0_a3,participant.p400_i1_a1,participant.p400_i1_a2,participant.p400_i1_a3,participant.p400_i2_a1,participant.p400_i2_a2,participant.p400_i2_a3,participant.p400_i3_a1,participant.p400_i3_a2,participant.p400_i3_a3 --delimiter , --output temp_pheno_batch_59.csv
# 批次 60 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 61/9460 (索引 60)，包含 1 个表型ID(s)...
# 执行命令 (批次 61): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p401_i0_a0,participant.p401_i0_a1,participant.p401_i0_a2,participant.p401_i0_a3,participant.p401_i0_a4,participant.p401_i0_a5,participant.p401_i0_a6,participant.p401_i0_a7,participant.p401_i0_a8,participant.p401_i0_a9,participant.p401_i0_a10,participant.p401_i0_a11,participant.p401_i1_a0,participant.p401_i1_a1,participant.p401_i1_a2,participant.p401_i1_a3,participant.p401_i1_a4,participant.p401_i1_a5,participant.p401_i1_a6,participant.p401_i1_a7,participant.p401_i1_a8,participant.p401_i1_a9,participant.p401_i1_a10,participant.p401_i1_a11,participant.p401_i2_a0,participant.p401_i2_a1,participant.p401_i2_a2,participant.p401_i2_a3,participant.p401_i2_a4,participant.p401_i2_a5,participant.p401_i2_a6,participant.p401_i2_a7,participant.p401_i2_a8,participant.p401_i2_a9,participant.p401_i2_a10,participant.p401_i2_a11,participant.p401_i3_a0,participant.p401_i3_a1,participant.p401_i3_a2,participant.p401_i3_a3,participant.p401_i3_a4,participant.p401_i3_a5,participant.p401_i3_a6,participant.p401_i3_a7,participant.p401_i3_a8,participant.p401_i3_a9,participant.p401_i3_a10,participant.p401_i3_a11 --delimiter , --output temp_pheno_batch_60.csv
# 执行批次 61 的 'dx extract_dataset' 时出错。返回码: 1
# STDERR (批次 61):
# {'type': 'DataTooLarge', 'message': 'Response too large'}
#
# STDOUT (批次 61):
# 无 STDOUT 输出。
# 批次 61 失败，建议检查错误并决定是否中止整个过程。当前设置为继续处理后续批次。
#
# 正在处理批次 62/9460 (索引 61)，包含 1 个表型ID(s)...
# 执行命令 (批次 62): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p402_i0_a0,participant.p402_i0_a1,participant.p402_i0_a2,participant.p402_i0_a3,participant.p402_i0_a4,participant.p402_i0_a5,participant.p402_i0_a6,participant.p402_i0_a7,participant.p402_i0_a8,participant.p402_i0_a9,participant.p402_i0_a10,participant.p402_i0_a11,participant.p402_i1_a0,participant.p402_i1_a1,participant.p402_i1_a2,participant.p402_i1_a3,participant.p402_i1_a4,participant.p402_i1_a5,participant.p402_i1_a6,participant.p402_i1_a7,participant.p402_i1_a8,participant.p402_i1_a9,participant.p402_i1_a10,participant.p402_i1_a11,participant.p402_i2_a0,participant.p402_i2_a1,participant.p402_i2_a2,participant.p402_i2_a3,participant.p402_i2_a4,participant.p402_i2_a5,participant.p402_i2_a6,participant.p402_i2_a7,participant.p402_i2_a8,participant.p402_i2_a9,participant.p402_i2_a10,participant.p402_i2_a11,participant.p402_i3_a0,participant.p402_i3_a1,participant.p402_i3_a2,participant.p402_i3_a3,participant.p402_i3_a4,participant.p402_i3_a5,participant.p402_i3_a6,participant.p402_i3_a7,participant.p402_i3_a8,participant.p402_i3_a9,participant.p402_i3_a10,participant.p402_i3_a11 --delimiter , --output temp_pheno_batch_61.csv
# 执行批次 62 的 'dx extract_dataset' 时出错。返回码: 1
# STDERR (批次 62):
# {'type': 'DataTooLarge', 'message': 'Response too large'}
#
# STDOUT (批次 62):
# 无 STDOUT 输出。
# 批次 62 失败，建议检查错误并决定是否中止整个过程。当前设置为继续处理后续批次。
#
# 正在处理批次 63/9460 (索引 62)，包含 1 个表型ID(s)...
# 执行命令 (批次 63): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p403_i0_a0,participant.p403_i0_a1,participant.p403_i0_a2,participant.p403_i0_a3,participant.p403_i0_a4,participant.p403_i0_a5,participant.p403_i0_a6,participant.p403_i0_a7,participant.p403_i0_a8,participant.p403_i0_a9,participant.p403_i0_a10,participant.p403_i0_a11,participant.p403_i1_a0,participant.p403_i1_a1,participant.p403_i1_a2,participant.p403_i1_a3,participant.p403_i1_a4,participant.p403_i1_a5,participant.p403_i1_a6,participant.p403_i1_a7,participant.p403_i1_a8,participant.p403_i1_a9,participant.p403_i1_a10,participant.p403_i1_a11,participant.p403_i2_a0,participant.p403_i2_a1,participant.p403_i2_a2,participant.p403_i2_a3,participant.p403_i2_a4,participant.p403_i2_a5,participant.p403_i2_a6,participant.p403_i2_a7,participant.p403_i2_a8,participant.p403_i2_a9,participant.p403_i2_a10,participant.p403_i2_a11,participant.p403_i3_a0,participant.p403_i3_a1,participant.p403_i3_a2,participant.p403_i3_a3,participant.p403_i3_a4,participant.p403_i3_a5,participant.p403_i3_a6,participant.p403_i3_a7,participant.p403_i3_a8,participant.p403_i3_a9,participant.p403_i3_a10,participant.p403_i3_a11 --delimiter , --output temp_pheno_batch_62.csv
# 执行批次 63 的 'dx extract_dataset' 时出错。返回码: 1
# STDERR (批次 63):
# WARNING:dxpy:[Sat May 17 07:03:18 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747465363.4664376, Request ID=unavailable. Waiting 1 seconds before retry 1 of 6...
# WARNING:dxpy:[Sat May 17 07:03:35 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747465399.5725558, Request ID=unavailable. Waiting 2 seconds before retry 2 of 6...
# INFO:dxpy:[Sat May 17 07:03:57 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: Recovered after 2 retries
# {'type': 'DataTooLarge', 'message': 'Response too large'}
#
# STDOUT (批次 63):
# 无 STDOUT 输出。
# 批次 63 失败，建议检查错误并决定是否中止整个过程。当前设置为继续处理后续批次。
#
# 正在处理批次 64/9460 (索引 63)，包含 1 个表型ID(s)...
# 执行命令 (批次 64): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p404_i0_a0,participant.p404_i0_a1,participant.p404_i0_a2,participant.p404_i0_a3,participant.p404_i0_a4,participant.p404_i0_a5,participant.p404_i0_a6,participant.p404_i0_a7,participant.p404_i0_a8,participant.p404_i0_a9,participant.p404_i0_a10,participant.p404_i0_a11,participant.p404_i1_a0,participant.p404_i1_a1,participant.p404_i1_a2,participant.p404_i1_a3,participant.p404_i1_a4,participant.p404_i1_a5,participant.p404_i1_a6,participant.p404_i1_a7,participant.p404_i1_a8,participant.p404_i1_a9,participant.p404_i1_a10,participant.p404_i1_a11,participant.p404_i2_a0,participant.p404_i2_a1,participant.p404_i2_a2,participant.p404_i2_a3,participant.p404_i2_a4,participant.p404_i2_a5,participant.p404_i2_a6,participant.p404_i2_a7,participant.p404_i2_a8,participant.p404_i2_a9,participant.p404_i2_a10,participant.p404_i2_a11,participant.p404_i3_a0,participant.p404_i3_a1,participant.p404_i3_a2,participant.p404_i3_a3,participant.p404_i3_a4,participant.p404_i3_a5,participant.p404_i3_a6,participant.p404_i3_a7,participant.p404_i3_a8,participant.p404_i3_a9,participant.p404_i3_a10,participant.p404_i3_a11 --delimiter , --output temp_pheno_batch_63.csv
# 执行批次 64 的 'dx extract_dataset' 时出错。返回码: 1
# STDERR (批次 64):
# WARNING:dxpy:[Sat May 17 07:04:45 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747465439.3535304, Request ID=unavailable. Waiting 1 seconds before retry 1 of 6...
# WARNING:dxpy:[Sat May 17 07:04:59 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747465486.6257796, Request ID=unavailable. Waiting 2 seconds before retry 2 of 6...
# INFO:dxpy:[Sat May 17 07:05:23 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: Recovered after 2 retries
# {'type': 'DataTooLarge', 'message': 'Response too large'}
#
# STDOUT (批次 64):
# 无 STDOUT 输出。
# 批次 64 失败，建议检查错误并决定是否中止整个过程。当前设置为继续处理后续批次。
#
# 正在处理批次 65/9460 (索引 64)，包含 1 个表型ID(s)...
# 执行命令 (批次 65): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p630_i0,participant.p630_i1,participant.p630_i2,participant.p630_i3 --delimiter , --output temp_pheno_batch_64.csv
# 批次 65 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 66/9460 (索引 65)，包含 1 个表型ID(s)...
# 执行命令 (批次 66): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p670_i0,participant.p670_i1,participant.p670_i2,participant.p670_i3 --delimiter , --output temp_pheno_batch_65.csv
# 批次 66 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 67/9460 (索引 66)，包含 1 个表型ID(s)...
# 执行命令 (批次 67): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p680_i0,participant.p680_i1,participant.p680_i2,participant.p680_i3 --delimiter , --output temp_pheno_batch_66.csv
# 批次 67 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 68/9460 (索引 67)，包含 1 个表型ID(s)...
# 执行命令 (批次 68): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p699_i0,participant.p699_i1,participant.p699_i2,participant.p699_i3 --delimiter , --output temp_pheno_batch_67.csv
# 批次 68 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 69/9460 (索引 68)，包含 1 个表型ID(s)...
# 执行命令 (批次 69): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p709_i0,participant.p709_i1,participant.p709_i2,participant.p709_i3 --delimiter , --output temp_pheno_batch_68.csv
# 批次 69 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 70/9460 (索引 69)，包含 1 个表型ID(s)...
# 执行命令 (批次 70): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p728_i0,participant.p728_i1,participant.p728_i2,participant.p728_i3 --delimiter , --output temp_pheno_batch_69.csv
# 批次 70 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 71/9460 (索引 70)，包含 1 个表型ID(s)...
# 执行命令 (批次 71): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p738_i0,participant.p738_i1,participant.p738_i2,participant.p738_i3 --delimiter , --output temp_pheno_batch_70.csv
# 批次 71 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 72/9460 (索引 71)，包含 1 个表型ID(s)...
# 执行命令 (批次 72): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p757_i0,participant.p757_i1,participant.p757_i2,participant.p757_i3 --delimiter , --output temp_pheno_batch_71.csv
# 批次 72 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 73/9460 (索引 72)，包含 1 个表型ID(s)...
# 执行命令 (批次 73): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p767_i0,participant.p767_i1,participant.p767_i2,participant.p767_i3 --delimiter , --output temp_pheno_batch_72.csv
# 批次 73 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 74/9460 (索引 73)，包含 1 个表型ID(s)...
# 执行命令 (批次 74): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p777_i0,participant.p777_i1,participant.p777_i2,participant.p777_i3 --delimiter , --output temp_pheno_batch_73.csv
# 批次 74 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 75/9460 (索引 74)，包含 1 个表型ID(s)...
# 执行命令 (批次 75): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p796_i0,participant.p796_i1,participant.p796_i2,participant.p796_i3 --delimiter , --output temp_pheno_batch_74.csv
# 批次 75 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 76/9460 (索引 75)，包含 1 个表型ID(s)...
# 执行命令 (批次 76): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p806_i0,participant.p806_i1,participant.p806_i2,participant.p806_i3 --delimiter , --output temp_pheno_batch_75.csv
# 批次 76 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 77/9460 (索引 76)，包含 1 个表型ID(s)...
# 执行命令 (批次 77): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p816_i0,participant.p816_i1,participant.p816_i2,participant.p816_i3 --delimiter , --output temp_pheno_batch_76.csv
# 批次 77 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 78/9460 (索引 77)，包含 1 个表型ID(s)...
# 执行命令 (批次 78): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p826_i0,participant.p826_i1,participant.p826_i2,participant.p826_i3 --delimiter , --output temp_pheno_batch_77.csv
# 批次 78 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 79/9460 (索引 78)，包含 1 个表型ID(s)...
# 执行命令 (批次 79): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p845_i0,participant.p845_i1,participant.p845_i2 --delimiter , --output temp_pheno_batch_78.csv
# 批次 79 数据加载成功。DataFrame shape: (502137, 4)
#
# 正在处理批次 80/9460 (索引 79)，包含 1 个表型ID(s)...
# 执行命令 (批次 80): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p864_i0,participant.p864_i1,participant.p864_i2,participant.p864_i3 --delimiter , --output temp_pheno_batch_79.csv
# 批次 80 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 81/9460 (索引 80)，包含 1 个表型ID(s)...
# 执行命令 (批次 81): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p874_i0,participant.p874_i1,participant.p874_i2,participant.p874_i3 --delimiter , --output temp_pheno_batch_80.csv
# 批次 81 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 82/9460 (索引 81)，包含 1 个表型ID(s)...
# 执行命令 (批次 82): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p884_i0,participant.p884_i1,participant.p884_i2,participant.p884_i3 --delimiter , --output temp_pheno_batch_81.csv
# 批次 82 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 83/9460 (索引 82)，包含 1 个表型ID(s)...
# 执行命令 (批次 83): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p894_i0,participant.p894_i1,participant.p894_i2,participant.p894_i3 --delimiter , --output temp_pheno_batch_82.csv
# 批次 83 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 84/9460 (索引 83)，包含 1 个表型ID(s)...
# 执行命令 (批次 84): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p904_i0,participant.p904_i1,participant.p904_i2,participant.p904_i3 --delimiter , --output temp_pheno_batch_83.csv
# 批次 84 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 85/9460 (索引 84)，包含 1 个表型ID(s)...
# 执行命令 (批次 85): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p914_i0,participant.p914_i1,participant.p914_i2,participant.p914_i3 --delimiter , --output temp_pheno_batch_84.csv
# 批次 85 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 86/9460 (索引 85)，包含 1 个表型ID(s)...
# 执行命令 (批次 86): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p924_i0,participant.p924_i1,participant.p924_i2,participant.p924_i3 --delimiter , --output temp_pheno_batch_85.csv
# 批次 86 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 87/9460 (索引 86)，包含 1 个表型ID(s)...
# 执行命令 (批次 87): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p943_i0,participant.p943_i1,participant.p943_i2,participant.p943_i3 --delimiter , --output temp_pheno_batch_86.csv
# 批次 87 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 88/9460 (索引 87)，包含 1 个表型ID(s)...
# 执行命令 (批次 88): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p971_i0,participant.p971_i1,participant.p971_i2,participant.p971_i3 --delimiter , --output temp_pheno_batch_87.csv
# 批次 88 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 89/9460 (索引 88)，包含 1 个表型ID(s)...
# 执行命令 (批次 89): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p981_i0,participant.p981_i1,participant.p981_i2,participant.p981_i3 --delimiter , --output temp_pheno_batch_88.csv
# 批次 89 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 90/9460 (索引 89)，包含 1 个表型ID(s)...
# 执行命令 (批次 90): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p991_i0,participant.p991_i1,participant.p991_i2,participant.p991_i3 --delimiter , --output temp_pheno_batch_89.csv
# 批次 90 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 91/9460 (索引 90)，包含 1 个表型ID(s)...
# 执行命令 (批次 91): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1001_i0,participant.p1001_i1,participant.p1001_i2,participant.p1001_i3 --delimiter , --output temp_pheno_batch_90.csv
# 批次 91 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 92/9460 (索引 91)，包含 1 个表型ID(s)...
# 执行命令 (批次 92): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1011_i0,participant.p1011_i1,participant.p1011_i2,participant.p1011_i3 --delimiter , --output temp_pheno_batch_91.csv
# 批次 92 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 93/9460 (索引 92)，包含 1 个表型ID(s)...
# 执行命令 (批次 93): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1021_i0,participant.p1021_i1,participant.p1021_i2,participant.p1021_i3 --delimiter , --output temp_pheno_batch_92.csv
# 批次 93 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 94/9460 (索引 93)，包含 1 个表型ID(s)...
# 执行命令 (批次 94): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1031_i0,participant.p1031_i1,participant.p1031_i2,participant.p1031_i3 --delimiter , --output temp_pheno_batch_93.csv
# 批次 94 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 95/9460 (索引 94)，包含 1 个表型ID(s)...
# 执行命令 (批次 95): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1050_i0,participant.p1050_i1,participant.p1050_i2,participant.p1050_i3 --delimiter , --output temp_pheno_batch_94.csv
# 批次 95 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 96/9460 (索引 95)，包含 1 个表型ID(s)...
# 执行命令 (批次 96): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1060_i0,participant.p1060_i1,participant.p1060_i2,participant.p1060_i3 --delimiter , --output temp_pheno_batch_95.csv
# 批次 96 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 97/9460 (索引 96)，包含 1 个表型ID(s)...
# 执行命令 (批次 97): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1070_i0,participant.p1070_i1,participant.p1070_i2,participant.p1070_i3 --delimiter , --output temp_pheno_batch_96.csv
# 批次 97 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 98/9460 (索引 97)，包含 1 个表型ID(s)...
# 执行命令 (批次 98): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1080_i0,participant.p1080_i1,participant.p1080_i2,participant.p1080_i3 --delimiter , --output temp_pheno_batch_97.csv
# 批次 98 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 99/9460 (索引 98)，包含 1 个表型ID(s)...
# 执行命令 (批次 99): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1090_i0,participant.p1090_i1,participant.p1090_i2,participant.p1090_i3 --delimiter , --output temp_pheno_batch_98.csv
# 批次 99 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 100/9460 (索引 99)，包含 1 个表型ID(s)...
# 执行命令 (批次 100): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1100_i0,participant.p1100_i1,participant.p1100_i2,participant.p1100_i3 --delimiter , --output temp_pheno_batch_99.csv
# 批次 100 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 101/9460 (索引 100)，包含 1 个表型ID(s)...
# 执行命令 (批次 101): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1110_i0,participant.p1110_i1,participant.p1110_i2,participant.p1110_i3 --delimiter , --output temp_pheno_batch_100.csv
# 批次 101 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 102/9460 (索引 101)，包含 1 个表型ID(s)...
# 执行命令 (批次 102): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1120_i0,participant.p1120_i1,participant.p1120_i2,participant.p1120_i3 --delimiter , --output temp_pheno_batch_101.csv
# 批次 102 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 103/9460 (索引 102)，包含 1 个表型ID(s)...
# 执行命令 (批次 103): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1130_i0,participant.p1130_i1,participant.p1130_i2,participant.p1130_i3 --delimiter , --output temp_pheno_batch_102.csv
# 批次 103 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 104/9460 (索引 103)，包含 1 个表型ID(s)...
# 执行命令 (批次 104): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1140_i0,participant.p1140_i1,participant.p1140_i2,participant.p1140_i3 --delimiter , --output temp_pheno_batch_103.csv
# 批次 104 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 105/9460 (索引 104)，包含 1 个表型ID(s)...
# 执行命令 (批次 105): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1150_i0,participant.p1150_i1,participant.p1150_i2,participant.p1150_i3 --delimiter , --output temp_pheno_batch_104.csv
# 批次 105 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 106/9460 (索引 105)，包含 1 个表型ID(s)...
# 执行命令 (批次 106): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1160_i0,participant.p1160_i1,participant.p1160_i2,participant.p1160_i3 --delimiter , --output temp_pheno_batch_105.csv
# 批次 106 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 107/9460 (索引 106)，包含 1 个表型ID(s)...
# 执行命令 (批次 107): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1170_i0,participant.p1170_i1,participant.p1170_i2,participant.p1170_i3 --delimiter , --output temp_pheno_batch_106.csv
# 批次 107 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 108/9460 (索引 107)，包含 1 个表型ID(s)...
# 执行命令 (批次 108): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1180_i0,participant.p1180_i1,participant.p1180_i2,participant.p1180_i3 --delimiter , --output temp_pheno_batch_107.csv
# 批次 108 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 109/9460 (索引 108)，包含 1 个表型ID(s)...
# 执行命令 (批次 109): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1190_i0,participant.p1190_i1,participant.p1190_i2,participant.p1190_i3 --delimiter , --output temp_pheno_batch_108.csv
# 批次 109 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 110/9460 (索引 109)，包含 1 个表型ID(s)...
# 执行命令 (批次 110): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1200_i0,participant.p1200_i1,participant.p1200_i2,participant.p1200_i3 --delimiter , --output temp_pheno_batch_109.csv
# dx STDERR (批次 110, 可能包含成功摘要):
# WARNING:dxpy:[Sat May 17 07:21:03 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747466451.020868, Request ID=unavailable. Waiting 1 seconds before retry 1 of 6...
# INFO:dxpy:[Sat May 17 07:21:28 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: Recovered after 1 retries
#
# 批次 110 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 111/9460 (索引 110)，包含 1 个表型ID(s)...
# 执行命令 (批次 111): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1210_i0,participant.p1210_i1,participant.p1210_i2,participant.p1210_i3 --delimiter , --output temp_pheno_batch_110.csv
# 批次 111 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 112/9460 (索引 111)，包含 1 个表型ID(s)...
# 执行命令 (批次 112): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1220_i0,participant.p1220_i1,participant.p1220_i2,participant.p1220_i3 --delimiter , --output temp_pheno_batch_111.csv
# 批次 112 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 113/9460 (索引 112)，包含 1 个表型ID(s)...
# 执行命令 (批次 113): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1239_i0,participant.p1239_i1,participant.p1239_i2,participant.p1239_i3 --delimiter , --output temp_pheno_batch_112.csv
# 批次 113 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 114/9460 (索引 113)，包含 1 个表型ID(s)...
# 执行命令 (批次 114): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1249_i0,participant.p1249_i1,participant.p1249_i2,participant.p1249_i3 --delimiter , --output temp_pheno_batch_113.csv
# 批次 114 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 115/9460 (索引 114)，包含 1 个表型ID(s)...
# 执行命令 (批次 115): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1259_i0,participant.p1259_i1,participant.p1259_i2,participant.p1259_i3 --delimiter , --output temp_pheno_batch_114.csv
# 批次 115 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 116/9460 (索引 115)，包含 1 个表型ID(s)...
# 执行命令 (批次 116): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1269_i0,participant.p1269_i1,participant.p1269_i2,participant.p1269_i3 --delimiter , --output temp_pheno_batch_115.csv
# 批次 116 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 117/9460 (索引 116)，包含 1 个表型ID(s)...
# 执行命令 (批次 117): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1279_i0,participant.p1279_i1,participant.p1279_i2,participant.p1279_i3 --delimiter , --output temp_pheno_batch_116.csv
# 批次 117 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 118/9460 (索引 117)，包含 1 个表型ID(s)...
# 执行命令 (批次 118): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1289_i0,participant.p1289_i1,participant.p1289_i2,participant.p1289_i3 --delimiter , --output temp_pheno_batch_117.csv
# 批次 118 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 119/9460 (索引 118)，包含 1 个表型ID(s)...
# 执行命令 (批次 119): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1299_i0,participant.p1299_i1,participant.p1299_i2,participant.p1299_i3 --delimiter , --output temp_pheno_batch_118.csv
# 批次 119 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 120/9460 (索引 119)，包含 1 个表型ID(s)...
# 执行命令 (批次 120): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1309_i0,participant.p1309_i1,participant.p1309_i2,participant.p1309_i3 --delimiter , --output temp_pheno_batch_119.csv
# 批次 120 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 121/9460 (索引 120)，包含 1 个表型ID(s)...
# 执行命令 (批次 121): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1319_i0,participant.p1319_i1,participant.p1319_i2,participant.p1319_i3 --delimiter , --output temp_pheno_batch_120.csv
# 批次 121 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 122/9460 (索引 121)，包含 1 个表型ID(s)...
# 执行命令 (批次 122): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1329_i0,participant.p1329_i1,participant.p1329_i2,participant.p1329_i3 --delimiter , --output temp_pheno_batch_121.csv
# 批次 122 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 123/9460 (索引 122)，包含 1 个表型ID(s)...
# 执行命令 (批次 123): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1339_i0,participant.p1339_i1,participant.p1339_i2,participant.p1339_i3 --delimiter , --output temp_pheno_batch_122.csv
# 批次 123 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 124/9460 (索引 123)，包含 1 个表型ID(s)...
# 执行命令 (批次 124): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1349_i0,participant.p1349_i1,participant.p1349_i2,participant.p1349_i3 --delimiter , --output temp_pheno_batch_123.csv
# 批次 124 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 125/9460 (索引 124)，包含 1 个表型ID(s)...
# 执行命令 (批次 125): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1359_i0,participant.p1359_i1,participant.p1359_i2,participant.p1359_i3 --delimiter , --output temp_pheno_batch_124.csv
# 批次 125 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 126/9460 (索引 125)，包含 1 个表型ID(s)...
# 执行命令 (批次 126): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1369_i0,participant.p1369_i1,participant.p1369_i2,participant.p1369_i3 --delimiter , --output temp_pheno_batch_125.csv
# 批次 126 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 127/9460 (索引 126)，包含 1 个表型ID(s)...
# 执行命令 (批次 127): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1379_i0,participant.p1379_i1,participant.p1379_i2,participant.p1379_i3 --delimiter , --output temp_pheno_batch_126.csv
# dx STDERR (批次 127, 可能包含成功摘要):
# WARNING:dxpy:[Sat May 17 07:27:21 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747466828.2105083, Request ID=unavailable. Waiting 1 seconds before retry 1 of 6...
# WARNING:dxpy:[Sat May 17 07:27:24 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747466842.775063, Request ID=unavailable. Waiting 2 seconds before retry 2 of 6...
# INFO:dxpy:[Sat May 17 07:27:36 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: Recovered after 2 retries
#
# 批次 127 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 128/9460 (索引 127)，包含 1 个表型ID(s)...
# 执行命令 (批次 128): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1389_i0,participant.p1389_i1,participant.p1389_i2,participant.p1389_i3 --delimiter , --output temp_pheno_batch_127.csv
# 批次 128 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 129/9460 (索引 128)，包含 1 个表型ID(s)...
# 执行命令 (批次 129): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1408_i0,participant.p1408_i1,participant.p1408_i2,participant.p1408_i3 --delimiter , --output temp_pheno_batch_128.csv
# 批次 129 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 130/9460 (索引 129)，包含 1 个表型ID(s)...
# 执行命令 (批次 130): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1418_i0,participant.p1418_i1,participant.p1418_i2,participant.p1418_i3 --delimiter , --output temp_pheno_batch_129.csv
# 批次 130 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 131/9460 (索引 130)，包含 1 个表型ID(s)...
# 执行命令 (批次 131): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1428_i0,participant.p1428_i1,participant.p1428_i2,participant.p1428_i3 --delimiter , --output temp_pheno_batch_130.csv
# 批次 131 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 132/9460 (索引 131)，包含 1 个表型ID(s)...
# 执行命令 (批次 132): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1438_i0,participant.p1438_i1,participant.p1438_i2,participant.p1438_i3 --delimiter , --output temp_pheno_batch_131.csv
# 批次 132 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 133/9460 (索引 132)，包含 1 个表型ID(s)...
# 执行命令 (批次 133): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1448_i0,participant.p1448_i1,participant.p1448_i2,participant.p1448_i3 --delimiter , --output temp_pheno_batch_132.csv
# 批次 133 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 134/9460 (索引 133)，包含 1 个表型ID(s)...
# 执行命令 (批次 134): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1458_i0,participant.p1458_i1,participant.p1458_i2,participant.p1458_i3 --delimiter , --output temp_pheno_batch_133.csv
# 批次 134 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 135/9460 (索引 134)，包含 1 个表型ID(s)...
# 执行命令 (批次 135): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1468_i0,participant.p1468_i1,participant.p1468_i2,participant.p1468_i3 --delimiter , --output temp_pheno_batch_134.csv
# 批次 135 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 136/9460 (索引 135)，包含 1 个表型ID(s)...
# 执行命令 (批次 136): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1478_i0,participant.p1478_i1,participant.p1478_i2,participant.p1478_i3 --delimiter , --output temp_pheno_batch_135.csv
# 批次 136 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 137/9460 (索引 136)，包含 1 个表型ID(s)...
# 执行命令 (批次 137): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1488_i0,participant.p1488_i1,participant.p1488_i2,participant.p1488_i3 --delimiter , --output temp_pheno_batch_136.csv
# 批次 137 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 138/9460 (索引 137)，包含 1 个表型ID(s)...
# 执行命令 (批次 138): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1498_i0,participant.p1498_i1,participant.p1498_i2,participant.p1498_i3 --delimiter , --output temp_pheno_batch_137.csv
# 批次 138 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 139/9460 (索引 138)，包含 1 个表型ID(s)...
# 执行命令 (批次 139): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1508_i0,participant.p1508_i1,participant.p1508_i2,participant.p1508_i3 --delimiter , --output temp_pheno_batch_138.csv
# 批次 139 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 140/9460 (索引 139)，包含 1 个表型ID(s)...
# 执行命令 (批次 140): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1518_i0,participant.p1518_i1,participant.p1518_i2,participant.p1518_i3 --delimiter , --output temp_pheno_batch_139.csv
# 批次 140 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 141/9460 (索引 140)，包含 1 个表型ID(s)...
# 执行命令 (批次 141): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1528_i0,participant.p1528_i1,participant.p1528_i2,participant.p1528_i3 --delimiter , --output temp_pheno_batch_140.csv
# 批次 141 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 142/9460 (索引 141)，包含 1 个表型ID(s)...
# 执行命令 (批次 142): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1538_i0,participant.p1538_i1,participant.p1538_i2,participant.p1538_i3 --delimiter , --output temp_pheno_batch_141.csv
# 批次 142 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 143/9460 (索引 142)，包含 1 个表型ID(s)...
# 执行命令 (批次 143): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1548_i0,participant.p1548_i1,participant.p1548_i2,participant.p1548_i3 --delimiter , --output temp_pheno_batch_142.csv
# 批次 143 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 144/9460 (索引 143)，包含 1 个表型ID(s)...
# 执行命令 (批次 144): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1558_i0,participant.p1558_i1,participant.p1558_i2,participant.p1558_i3 --delimiter , --output temp_pheno_batch_143.csv
# dx STDERR (批次 144, 可能包含成功摘要):
# WARNING:dxpy:[Sat May 17 07:33:02 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747467181.3920276, Request ID=unavailable. Waiting 1 seconds before retry 1 of 6...
# INFO:dxpy:[Sat May 17 07:33:19 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: Recovered after 1 retries
#
# 批次 144 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 145/9460 (索引 144)，包含 1 个表型ID(s)...
# 执行命令 (批次 145): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1568_i0,participant.p1568_i1,participant.p1568_i2,participant.p1568_i3 --delimiter , --output temp_pheno_batch_144.csv
# 批次 145 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 146/9460 (索引 145)，包含 1 个表型ID(s)...
# 执行命令 (批次 146): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1578_i0,participant.p1578_i1,participant.p1578_i2,participant.p1578_i3 --delimiter , --output temp_pheno_batch_145.csv
# 批次 146 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 147/9460 (索引 146)，包含 1 个表型ID(s)...
# 执行命令 (批次 147): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1588_i0,participant.p1588_i1,participant.p1588_i2,participant.p1588_i3 --delimiter , --output temp_pheno_batch_146.csv
# 批次 147 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 148/9460 (索引 147)，包含 1 个表型ID(s)...
# 执行命令 (批次 148): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1598_i0,participant.p1598_i1,participant.p1598_i2,participant.p1598_i3 --delimiter , --output temp_pheno_batch_147.csv
# 批次 148 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 149/9460 (索引 148)，包含 1 个表型ID(s)...
# 执行命令 (批次 149): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1608_i0,participant.p1608_i1,participant.p1608_i2,participant.p1608_i3 --delimiter , --output temp_pheno_batch_148.csv
# 批次 149 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 150/9460 (索引 149)，包含 1 个表型ID(s)...
# 执行命令 (批次 150): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1618_i0,participant.p1618_i1,participant.p1618_i2,participant.p1618_i3 --delimiter , --output temp_pheno_batch_149.csv
# dx STDERR (批次 150, 可能包含成功摘要):
# WARNING:dxpy:[Sat May 17 07:35:13 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747467300.4473555, Request ID=unavailable. Waiting 1 seconds before retry 1 of 6...
# INFO:dxpy:[Sat May 17 07:35:18 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: Recovered after 1 retries
#
# 批次 150 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 151/9460 (索引 150)，包含 1 个表型ID(s)...
# 执行命令 (批次 151): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1628_i0,participant.p1628_i1,participant.p1628_i2,participant.p1628_i3 --delimiter , --output temp_pheno_batch_150.csv
# 批次 151 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 152/9460 (索引 151)，包含 1 个表型ID(s)...
# 执行命令 (批次 152): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1647_i0,participant.p1647_i1,participant.p1647_i2 --delimiter , --output temp_pheno_batch_151.csv
# 批次 152 数据加载成功。DataFrame shape: (502137, 4)
#
# 正在处理批次 153/9460 (索引 152)，包含 1 个表型ID(s)...
# 执行命令 (批次 153): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1677_i0,participant.p1677_i1,participant.p1677_i2 --delimiter , --output temp_pheno_batch_152.csv
# 批次 153 数据加载成功。DataFrame shape: (502137, 4)
#
# 正在处理批次 154/9460 (索引 153)，包含 1 个表型ID(s)...
# 执行命令 (批次 154): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1687_i0,participant.p1687_i1,participant.p1687_i2 --delimiter , --output temp_pheno_batch_153.csv
# 批次 154 数据加载成功。DataFrame shape: (502137, 4)
#
# 正在处理批次 155/9460 (索引 154)，包含 1 个表型ID(s)...
# 执行命令 (批次 155): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1697_i0,participant.p1697_i1,participant.p1697_i2 --delimiter , --output temp_pheno_batch_154.csv
# 批次 155 数据加载成功。DataFrame shape: (502137, 4)
#
# 正在处理批次 156/9460 (索引 155)，包含 1 个表型ID(s)...
# 执行命令 (批次 156): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1707_i0,participant.p1707_i1,participant.p1707_i2 --delimiter , --output temp_pheno_batch_155.csv
# 批次 156 数据加载成功。DataFrame shape: (502137, 4)
#
# 正在处理批次 157/9460 (索引 156)，包含 1 个表型ID(s)...
# 执行命令 (批次 157): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1717_i0,participant.p1717_i1,participant.p1717_i2 --delimiter , --output temp_pheno_batch_156.csv
# 批次 157 数据加载成功。DataFrame shape: (502137, 4)
#
# 正在处理批次 158/9460 (索引 157)，包含 1 个表型ID(s)...
# 执行命令 (批次 158): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1727_i0,participant.p1727_i1,participant.p1727_i2 --delimiter , --output temp_pheno_batch_157.csv
# 批次 158 数据加载成功。DataFrame shape: (502137, 4)
#
# 正在处理批次 159/9460 (索引 158)，包含 1 个表型ID(s)...
# 执行命令 (批次 159): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1737_i0,participant.p1737_i1,participant.p1737_i2 --delimiter , --output temp_pheno_batch_158.csv
# 批次 159 数据加载成功。DataFrame shape: (502137, 4)
#
# 正在处理批次 160/9460 (索引 159)，包含 1 个表型ID(s)...
# 执行命令 (批次 160): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1747_i0,participant.p1747_i1,participant.p1747_i2 --delimiter , --output temp_pheno_batch_159.csv
# 批次 160 数据加载成功。DataFrame shape: (502137, 4)
#
# 正在处理批次 161/9460 (索引 160)，包含 1 个表型ID(s)...
# 执行命令 (批次 161): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1757_i0,participant.p1757_i1,participant.p1757_i2,participant.p1757_i3 --delimiter , --output temp_pheno_batch_160.csv
# 批次 161 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 162/9460 (索引 161)，包含 1 个表型ID(s)...
# 执行命令 (批次 162): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p1767_i0,participant.p1767_i1,participant.p1767_i2,participant.p1767_i3 --delimiter , --output temp_pheno_batch_161.csv
# 批次 162 数据加载成功。DataFrame shape: (502137, 5)
#
# 正在处理批次 163/9460 (索引 162)，包含 1 个表型ID(s)...
# ...
# 执行批次 483 的 'dx extract_dataset' 时出错。返回码: 1
# STDERR (批次 483):
# {'type': 'DataTooLarge', 'message': 'Response too large'}
#
# STDOUT (批次 483):
# 无 STDOUT 输出。
# 批次 483 失败，建议检查错误并决定是否中止整个过程。当前设置为继续处理后续批次。
#
# 正在处理批次 484/9460 (索引 483)，包含 1 个表型ID(s)...
# 执行命令 (批次 484): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5082_i0_a0,participant.p5082_i0_a1,participant.p5082_i0_a2,participant.p5082_i0_a3,participant.p5082_i0_a4,participant.p5082_i0_a5,participant.p5082_i0_a6,participant.p5082_i0_a7,participant.p5082_i0_a8,participant.p5082_i0_a9,participant.p5082_i0_a10,participant.p5082_i0_a11,participant.p5082_i0_a12,participant.p5082_i0_a13,participant.p5082_i0_a14,participant.p5082_i0_a15,participant.p5082_i1_a0,participant.p5082_i1_a1,participant.p5082_i1_a2,participant.p5082_i1_a3,participant.p5082_i1_a4,participant.p5082_i1_a5,participant.p5082_i1_a6,participant.p5082_i1_a7,participant.p5082_i1_a8,participant.p5082_i1_a9,participant.p5082_i1_a10,participant.p5082_i1_a11,participant.p5082_i1_a12,participant.p5082_i1_a13,participant.p5082_i1_a14,participant.p5082_i1_a15 --delimiter , --output temp_pheno_batch_483.csv
# 执行批次 484 的 'dx extract_dataset' 时出错。返回码: 1
# STDERR (批次 484):
# {'type': 'DataTooLarge', 'message': 'Response too large'}
#
# STDOUT (批次 484):
# 无 STDOUT 输出。
# 批次 484 失败，建议检查错误并决定是否中止整个过程。当前设置为继续处理后续批次。
#
# 正在处理批次 485/9460 (索引 484)，包含 1 个表型ID(s)...
# 执行命令 (批次 485): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5083_i0_a0,participant.p5083_i0_a1,participant.p5083_i0_a2,participant.p5083_i0_a3,participant.p5083_i0_a4,participant.p5083_i0_a5,participant.p5083_i0_a6,participant.p5083_i0_a7,participant.p5083_i0_a8,participant.p5083_i0_a9,participant.p5083_i0_a10,participant.p5083_i0_a11,participant.p5083_i0_a12,participant.p5083_i0_a13,participant.p5083_i0_a14,participant.p5083_i0_a15,participant.p5083_i1_a0,participant.p5083_i1_a1,participant.p5083_i1_a2,participant.p5083_i1_a3,participant.p5083_i1_a4,participant.p5083_i1_a5,participant.p5083_i1_a6,participant.p5083_i1_a7,participant.p5083_i1_a8,participant.p5083_i1_a9,participant.p5083_i1_a10,participant.p5083_i1_a11,participant.p5083_i1_a12,participant.p5083_i1_a13,participant.p5083_i1_a14,participant.p5083_i1_a15 --delimiter , --output temp_pheno_batch_484.csv
# 执行批次 485 的 'dx extract_dataset' 时出错。返回码: 1
# STDERR (批次 485):
# WARNING:dxpy:[Sat May 17 10:32:44 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747477946.0667384, Request ID=unavailable. Waiting 1 seconds before retry 1 of 6...
# INFO:dxpy:[Sat May 17 10:33:33 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: Recovered after 1 retries
# {'type': 'DataTooLarge', 'message': 'Response too large'}
#
# STDOUT (批次 485):
# 无 STDOUT 输出。
# 批次 485 失败，建议检查错误并决定是否中止整个过程。当前设置为继续处理后续批次。
#
# 正在处理批次 486/9460 (索引 485)，包含 1 个表型ID(s)...
# 执行命令 (批次 486): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5084_i0_a0,participant.p5084_i0_a1,participant.p5084_i0_a2,participant.p5084_i0_a3,participant.p5084_i0_a4,participant.p5084_i0_a5,participant.p5084_i0_a6,participant.p5084_i0_a7,participant.p5084_i0_a8,participant.p5084_i0_a9,participant.p5084_i1_a0,participant.p5084_i1_a1,participant.p5084_i1_a2,participant.p5084_i1_a3,participant.p5084_i1_a4,participant.p5084_i1_a5,participant.p5084_i1_a6,participant.p5084_i1_a7,participant.p5084_i1_a8,participant.p5084_i1_a9 --delimiter , --output temp_pheno_batch_485.csv
# 批次 486 数据加载成功。DataFrame shape: (502137, 21)
#
# 正在处理批次 487/9460 (索引 486)，包含 1 个表型ID(s)...
# 执行命令 (批次 487): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5085_i0_a0,participant.p5085_i0_a1,participant.p5085_i0_a2,participant.p5085_i0_a3,participant.p5085_i0_a4,participant.p5085_i0_a5,participant.p5085_i0_a6,participant.p5085_i0_a7,participant.p5085_i0_a8,participant.p5085_i0_a9,participant.p5085_i1_a0,participant.p5085_i1_a1,participant.p5085_i1_a2,participant.p5085_i1_a3,participant.p5085_i1_a4,participant.p5085_i1_a5,participant.p5085_i1_a6,participant.p5085_i1_a7,participant.p5085_i1_a8,participant.p5085_i1_a9 --delimiter , --output temp_pheno_batch_486.csv
# 批次 487 数据加载成功。DataFrame shape: (502137, 21)
#
# 正在处理批次 488/9460 (索引 487)，包含 1 个表型ID(s)...
# 执行命令 (批次 488): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5086_i0_a0,participant.p5086_i0_a1,participant.p5086_i0_a2,participant.p5086_i0_a3,participant.p5086_i0_a4,participant.p5086_i0_a5,participant.p5086_i0_a6,participant.p5086_i0_a7,participant.p5086_i0_a8,participant.p5086_i0_a9,participant.p5086_i1_a0,participant.p5086_i1_a1,participant.p5086_i1_a2,participant.p5086_i1_a3,participant.p5086_i1_a4,participant.p5086_i1_a5,participant.p5086_i1_a6,participant.p5086_i1_a7,participant.p5086_i1_a8,participant.p5086_i1_a9 --delimiter , --output temp_pheno_batch_487.csv
# 批次 488 数据加载成功。DataFrame shape: (502137, 21)
#
# 正在处理批次 489/9460 (索引 488)，包含 1 个表型ID(s)...
# 执行命令 (批次 489): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5087_i0_a0,participant.p5087_i0_a1,participant.p5087_i0_a2,participant.p5087_i0_a3,participant.p5087_i0_a4,participant.p5087_i0_a5,participant.p5087_i0_a6,participant.p5087_i0_a7,participant.p5087_i0_a8,participant.p5087_i0_a9,participant.p5087_i1_a0,participant.p5087_i1_a1,participant.p5087_i1_a2,participant.p5087_i1_a3,participant.p5087_i1_a4,participant.p5087_i1_a5,participant.p5087_i1_a6,participant.p5087_i1_a7,participant.p5087_i1_a8,participant.p5087_i1_a9 --delimiter , --output temp_pheno_batch_488.csv
# dx STDERR (批次 489, 可能包含成功摘要):
# WARNING:dxpy:[Sat May 17 10:35:56 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: The server encountered an internal error, code 500. Request Time=1747478132.6265616, Request ID=unavailable. Waiting 1 seconds before retry 1 of 6...
# INFO:dxpy:[Sat May 17 10:36:16 2025] POST http://10.0.3.1:8124/VIZ/SRV/data/3.0/record-GvQp8V8JJ68073BBp2PjfgKg/raw: Recovered after 1 retries
#
# 批次 489 数据加载成功。DataFrame shape: (502137, 21)
#
# 正在处理批次 490/9460 (索引 489)，包含 1 个表型ID(s)...
# 执行命令 (批次 490): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5088_i0_a0,participant.p5088_i0_a1,participant.p5088_i0_a2,participant.p5088_i0_a3,participant.p5088_i0_a4,participant.p5088_i0_a5,participant.p5088_i0_a6,participant.p5088_i0_a7,participant.p5088_i0_a8,participant.p5088_i0_a9,participant.p5088_i1_a0,participant.p5088_i1_a1,participant.p5088_i1_a2,participant.p5088_i1_a3,participant.p5088_i1_a4,participant.p5088_i1_a5,participant.p5088_i1_a6,participant.p5088_i1_a7,participant.p5088_i1_a8,participant.p5088_i1_a9 --delimiter , --output temp_pheno_batch_489.csv
# 批次 490 数据加载成功。DataFrame shape: (502137, 21)
#
# 正在处理批次 491/9460 (索引 490)，包含 1 个表型ID(s)...
# 执行命令 (批次 491): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5089_i0_a0,participant.p5089_i0_a1,participant.p5089_i0_a2,participant.p5089_i0_a3,participant.p5089_i0_a4,participant.p5089_i0_a5,participant.p5089_i0_a6,participant.p5089_i0_a7,participant.p5089_i0_a8,participant.p5089_i0_a9,participant.p5089_i1_a0,participant.p5089_i1_a1,participant.p5089_i1_a2,participant.p5089_i1_a3,participant.p5089_i1_a4,participant.p5089_i1_a5,participant.p5089_i1_a6,participant.p5089_i1_a7,participant.p5089_i1_a8,participant.p5089_i1_a9 --delimiter , --output temp_pheno_batch_490.csv
# 批次 491 数据加载成功。DataFrame shape: (502137, 21)
#
# 正在处理批次 492/9460 (索引 491)，包含 1 个表型ID(s)...
# 执行命令 (批次 492): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5090_i0_a0,participant.p5090_i0_a1,participant.p5090_i0_a2,participant.p5090_i0_a3,participant.p5090_i0_a4,participant.p5090_i0_a5,participant.p5090_i0_a6,participant.p5090_i0_a7,participant.p5090_i0_a8,participant.p5090_i1_a0,participant.p5090_i1_a1,participant.p5090_i1_a2,participant.p5090_i1_a3,participant.p5090_i1_a4,participant.p5090_i1_a5,participant.p5090_i1_a6,participant.p5090_i1_a7,participant.p5090_i1_a8 --delimiter , --output temp_pheno_batch_491.csv
# 批次 492 数据加载成功。DataFrame shape: (502137, 19)
#
# 正在处理批次 493/9460 (索引 492)，包含 1 个表型ID(s)...
# 执行命令 (批次 493): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5091_i0_a0,participant.p5091_i0_a1,participant.p5091_i0_a2,participant.p5091_i0_a3,participant.p5091_i0_a4,participant.p5091_i0_a5,participant.p5091_i0_a6,participant.p5091_i1_a0,participant.p5091_i1_a1,participant.p5091_i1_a2,participant.p5091_i1_a3,participant.p5091_i1_a4,participant.p5091_i1_a5,participant.p5091_i1_a6 --delimiter , --output temp_pheno_batch_492.csv
# 批次 493 数据加载成功。DataFrame shape: (502137, 15)
#
# 正在处理批次 494/9460 (索引 493)，包含 1 个表型ID(s)...
# 执行命令 (批次 494): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5096_i0_a0,participant.p5096_i0_a1,participant.p5096_i0_a2,participant.p5096_i0_a3,participant.p5096_i0_a4,participant.p5096_i0_a5,participant.p5096_i1_a0,participant.p5096_i1_a1,participant.p5096_i1_a2,participant.p5096_i1_a3,participant.p5096_i1_a4,participant.p5096_i1_a5 --delimiter , --output temp_pheno_batch_493.csv
# 批次 494 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 495/9460 (索引 494)，包含 1 个表型ID(s)...
# 执行命令 (批次 495): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5097_i0_a0,participant.p5097_i0_a1,participant.p5097_i0_a2,participant.p5097_i0_a3,participant.p5097_i0_a4,participant.p5097_i0_a5,participant.p5097_i1_a0,participant.p5097_i1_a1,participant.p5097_i1_a2,participant.p5097_i1_a3,participant.p5097_i1_a4,participant.p5097_i1_a5 --delimiter , --output temp_pheno_batch_494.csv
# 批次 495 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 496/9460 (索引 495)，包含 1 个表型ID(s)...
# 执行命令 (批次 496): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5098_i0_a0,participant.p5098_i0_a1,participant.p5098_i0_a2,participant.p5098_i0_a3,participant.p5098_i0_a4,participant.p5098_i0_a5,participant.p5098_i1_a0,participant.p5098_i1_a1,participant.p5098_i1_a2,participant.p5098_i1_a3,participant.p5098_i1_a4,participant.p5098_i1_a5 --delimiter , --output temp_pheno_batch_495.csv
# 批次 496 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 497/9460 (索引 496)，包含 1 个表型ID(s)...
# 执行命令 (批次 497): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5099_i0_a0,participant.p5099_i0_a1,participant.p5099_i0_a2,participant.p5099_i0_a3,participant.p5099_i0_a4,participant.p5099_i0_a5,participant.p5099_i1_a0,participant.p5099_i1_a1,participant.p5099_i1_a2,participant.p5099_i1_a3,participant.p5099_i1_a4,participant.p5099_i1_a5 --delimiter , --output temp_pheno_batch_496.csv
# 批次 497 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 498/9460 (索引 497)，包含 1 个表型ID(s)...
# 执行命令 (批次 498): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5100_i0_a0,participant.p5100_i0_a1,participant.p5100_i0_a2,participant.p5100_i0_a3,participant.p5100_i0_a4,participant.p5100_i0_a5,participant.p5100_i1_a0,participant.p5100_i1_a1,participant.p5100_i1_a2,participant.p5100_i1_a3,participant.p5100_i1_a4,participant.p5100_i1_a5 --delimiter , --output temp_pheno_batch_497.csv
# 批次 498 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 499/9460 (索引 498)，包含 1 个表型ID(s)...
# 执行命令 (批次 499): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5101_i0_a0,participant.p5101_i0_a1,participant.p5101_i0_a2,participant.p5101_i0_a3,participant.p5101_i0_a4,participant.p5101_i0_a5,participant.p5101_i1_a0,participant.p5101_i1_a1,participant.p5101_i1_a2,participant.p5101_i1_a3,participant.p5101_i1_a4,participant.p5101_i1_a5 --delimiter , --output temp_pheno_batch_498.csv
# 批次 499 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 500/9460 (索引 499)，包含 1 个表型ID(s)...
# 执行命令 (批次 500): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5102_i0_a0,participant.p5102_i0_a1,participant.p5102_i0_a2,participant.p5102_i0_a3,participant.p5102_i0_a4,participant.p5102_i0_a5,participant.p5102_i1_a0,participant.p5102_i1_a1,participant.p5102_i1_a2,participant.p5102_i1_a3,participant.p5102_i1_a4,participant.p5102_i1_a5 --delimiter , --output temp_pheno_batch_499.csv
# 批次 500 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 501/9460 (索引 500)，包含 1 个表型ID(s)...
# 执行命令 (批次 501): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5103_i0_a0,participant.p5103_i0_a1,participant.p5103_i0_a2,participant.p5103_i0_a3,participant.p5103_i0_a4,participant.p5103_i0_a5,participant.p5103_i1_a0,participant.p5103_i1_a1,participant.p5103_i1_a2,participant.p5103_i1_a3,participant.p5103_i1_a4,participant.p5103_i1_a5 --delimiter , --output temp_pheno_batch_500.csv
# 批次 501 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 502/9460 (索引 501)，包含 1 个表型ID(s)...
# 执行命令 (批次 502): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5104_i0_a0,participant.p5104_i0_a1,participant.p5104_i0_a2,participant.p5104_i0_a3,participant.p5104_i0_a4,participant.p5104_i0_a5,participant.p5104_i1_a0,participant.p5104_i1_a1,participant.p5104_i1_a2,participant.p5104_i1_a3,participant.p5104_i1_a4,participant.p5104_i1_a5 --delimiter , --output temp_pheno_batch_501.csv
# 批次 502 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 503/9460 (索引 502)，包含 1 个表型ID(s)...
# 执行命令 (批次 503): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5105_i0_a0,participant.p5105_i0_a1,participant.p5105_i0_a2,participant.p5105_i0_a3,participant.p5105_i0_a4,participant.p5105_i0_a5,participant.p5105_i1_a0,participant.p5105_i1_a1,participant.p5105_i1_a2,participant.p5105_i1_a3,participant.p5105_i1_a4,participant.p5105_i1_a5 --delimiter , --output temp_pheno_batch_502.csv
# 批次 503 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 504/9460 (索引 503)，包含 1 个表型ID(s)...
# 执行命令 (批次 504): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5106_i0_a0,participant.p5106_i0_a1,participant.p5106_i0_a2,participant.p5106_i0_a3,participant.p5106_i0_a4,participant.p5106_i0_a5,participant.p5106_i1_a0,participant.p5106_i1_a1,participant.p5106_i1_a2,participant.p5106_i1_a3,participant.p5106_i1_a4,participant.p5106_i1_a5 --delimiter , --output temp_pheno_batch_503.csv
# 批次 504 数据加载成功。DataFrame shape: (502137, 13)
#
# 正在处理批次 505/9460 (索引 504)，包含 1 个表型ID(s)...
# 执行命令 (批次 505): dx extract_dataset project-GvQgb10JjKY3XGbpZbGVg0v3:record-GvQp8V8JJ68073BBp2PjfgKg --fields participant.eid,participant.p5107_i0_a0,participant.p5107_i0_a1,participant.p5107_i0_a2,participant.p5107_i0_a3,participant.p5107_i0_a4,participant.p5107_i0_a5,participant.p5107_i1_a0,participant.p5107_i1_a1,participant.p5107_i1_a2,participant.p5107_i1_a3,participant.p5107_i1_a4,participant.p5107_i1_a5 --delimiter , --output temp_pheno_batch_504.csv

# %%
# 单元格 8: 重命名和排序列
processed_phenotype_df = None
final_output_filename = "ukbiobank_phenotypes_r_compatible.csv"

if phenotype_df is not None:
    print("开始处理已加载的表型数据...")
    # dx extract_dataset --fields-file 提取出的列名是不带 'participant.' 前缀的
    # 所以我们直接使用这些列名进行转换和排序
    processed_phenotype_df = phenotype_df.copy() 

    original_columns = processed_phenotype_df.columns.tolist()
    renamed_columns_map = {} 
    final_columns_ordered_r_names = [] # 存储R兼容的列名，用于最终排序

    # 1. 处理 'eid' -> 'userId'
    eid_col_original = None
    if 'eid' in original_columns: # dx extract --fields-file 应该输出不带前缀的 'eid'
        eid_col_original = 'eid'
    
    if eid_col_original:
        renamed_columns_map[eid_col_original] = 'userId'
        final_columns_ordered_r_names.append('userId') # userId 应该是第一列
    else:
        print("错误：在提取的数据中未找到 'eid' 列。无法设置 'userId'。")
        # 脚本可能需要停止或采取其他措施
        
    # 2. 处理其他表型列
    temp_pheno_cols_for_sorting = [] # 存储包含排序信息的字典列表
    for col_name in original_columns:
        if col_name == eid_col_original: # 跳过已处理的 eid
            continue

        # col_name 此时应该是原始的UKB字段名，如 pXXXX_iY_aZ (不带 'participant.' 前缀)
        r_compat_name = convert_phenotype_name(col_name) # 'eid' 已被上面处理
        renamed_columns_map[col_name] = r_compat_name

        # 提取 varid, instance, array 用于排序
        match = re.match(r'x(\d+)(?:_(\d+))?(?:_(\d+))?$', r_compat_name)
        if match:
            varid = int(match.group(1))
            instance_str = match.group(2)
            array_str = match.group(3)
            instance = int(instance_str) if instance_str is not None else 0
            array_val = int(array_str) if array_str is not None else 0
            temp_pheno_cols_for_sorting.append({
                'original': col_name,      # 原始列名 (e.g., 'p21003_0_0')
                'r_name': r_compat_name,   # R兼容列名 (e.g., 'x21003_0_0')
                'varid': varid,
                'instance': instance,
                'array': array_val
            })
        else: # 处理非标准格式的列名 (convert_phenotype_name已处理，这里主要用于排序)
             temp_pheno_cols_for_sorting.append({
                'original': col_name,
                'r_name': r_compat_name,
                'varid': float('inf'), # 使其排在标准格式之后
                'instance': float('inf'),
                'array': float('inf')
            })
            if r_compat_name not in final_columns_ordered_r_names: # 避免userId重复
                 print(f"警告：列 '{col_name}' (转换为 '{r_compat_name}') 未能解析出varid/instance/array，将按名称排序。")


    # 按 varid, then instance, then array 排序表型列
    sorted_pheno_cols_info = sorted(temp_pheno_cols_for_sorting, key=lambda x: (x['varid'], x['instance'], x['array'], x['r_name']))

    for item in sorted_pheno_cols_info:
        if item['r_name'] not in final_columns_ordered_r_names: 
            final_columns_ordered_r_names.append(item['r_name'])
    
    # 应用重命名
    processed_phenotype_df.rename(columns=renamed_columns_map, inplace=True)

    # 按最终顺序排序列
    try:
        # 确保 final_columns_ordered_r_names 中的所有列都存在于 DataFrame 中
        existing_final_columns = [col for col in final_columns_ordered_r_names if col in processed_phenotype_df.columns]
        
        # 如果 'userId' 由于某种原因不在列表的开头 (例如，它是唯一的非数字ID字段且排序逻辑不同)
        # 或者某些列丢失了，这里尝试确保 'userId' 是第一列 (如果它存在)
        if 'userId' in processed_phenotype_df.columns:
            if 'userId' in existing_final_columns:
                existing_final_columns.remove('userId')
            existing_final_columns.insert(0, 'userId')
        else: # 如果 userId 真的丢失了，这是一个严重问题
            print("严重错误: 'userId' 列在重命名后丢失。")
        
        # 去重，以防万一 (userId 可能在 renamed_columns_map 和 final_columns_ordered_r_names 中都出现)
        seen = set()
        unique_existing_final_columns = [x for x in existing_final_columns if not (x in seen or seen.add(x))]

        processed_phenotype_df = processed_phenotype_df[unique_existing_final_columns]
        print("列已成功重命名并排序。")
        print("处理后的表型数据 (前5行):")
        print(processed_phenotype_df.head())

    except KeyError as e:
        print(f"排序列时发生 KeyError: {e}。可能是某些列未能正确重命名或意外丢失。")
        print("重命名后的可用列:", processed_phenotype_df.columns.tolist())
        print("尝试使用可用列继续。")
        available_cols = [col for col in final_columns_ordered_r_names if col in processed_phenotype_df.columns]
        if 'userId' in processed_phenotype_df.columns and 'userId' not in available_cols:
            available_cols.insert(0, 'userId')
        
        seen = set()
        unique_available_cols = [x for x in available_cols if not (x in seen or seen.add(x))]

        if unique_available_cols:
             processed_phenotype_df = processed_phenotype_df[unique_available_cols]
             print("已使用可用列重新组织 DataFrame。")
             print(processed_phenotype_df.head())
        else:
            print("没有可用的列来创建最终的 DataFrame。")
            processed_phenotype_df = None
else:
    print("原始表型数据 (phenotype_df) 未成功加载，跳过处理步骤。")

# %%
# 单元格 9: 保存最终的 CSV 文件
if processed_phenotype_df is not None:
    try:
        processed_phenotype_df.to_csv(final_output_filename, index=False, na_rep='NA') # R 中常用的缺失值表示
        print(f"最终表型数据已保存到 '{final_output_filename}'。")
        print(f"文件格式: CSV, 逗号分隔, {processed_phenotype_df.shape[0]} 行, {processed_phenotype_df.shape[1]} 列。")
        if not processed_phenotype_df.empty:
            print(f"第一列: '{processed_phenotype_df.columns[0]}'")
            print("最终数据的前5行示例:")
            print(processed_phenotype_df.head())
        else:
            print("警告：最终的DataFrame为空。")

        # 可选：上传到 UKB RAP (根据需要取消注释并调整路径)
        if project_id: # 确保 project_id 已定义
             dx_upload_folder = "/output_data/" # 例如，在项目中的 output_data 文件夹
             print(f"准备上传 '{final_output_filename}' 到 UKB RAP 项目 '{project_id}' 的文件夹 '{dx_upload_folder}'...")
             try:
                 # 确保文件夹存在
                 dxpy.DXProject(project_id).new_folder(dx_upload_folder, parents=True)
                 dxpy.upload_local_file(filename=final_output_filename, project=project_id, folder=dx_upload_folder)
                 print(f"文件成功上传到 '{dx_upload_folder}{final_output_filename}'")
             except Exception as e_upload:
                 print(f"上传文件到 DNAnexus 时出错: {e_upload}")
        else:
            print("项目ID未定义，跳过上传步骤。")


    except Exception as e:
        print(f"保存最终 CSV 时出错: {e}")
else:
    print("没有处理好的表型数据可供保存。")

print("脚本执行完毕。")
